# %%
import pandas as pd
import numpy as np

# %%
def read_csv():
    df = pd.read_csv
    return df

# %%
df= pd.read_csv("Compressed Mortality,2010-2015 (2).csv")

# %%
df
# Out:
#     Notes       State  State Code    Year  Year Code  \
# 0     NaN     Arizona         4.0  2013.0     2013.0
# 1     NaN     Arizona         4.0  2014.0     2014.0
# 2     NaN    Arkansas         5.0  2012.0     2012.0
# 3     NaN    Arkansas         5.0  2014.0     2014.0
# 4     NaN  California         6.0  2010.0     2010.0
# ..    ...         ...         ...     ...        ...
# 187   NaN  Washington        53.0  2014.0     2014.0
# 188   NaN   Wisconsin        55.0  2011.0     2011.0
# 189   NaN   Wisconsin        55.0  2014.0     2014.0
# 190   NaN   Wisconsin        55.0  2015.0     2015.0
# 191   ---         NaN         NaN     NaN        NaN
#
#                           Race Race Code         Hispanic Origin  \
# 0                        White    2106-3  Not Hispanic or Latino
# 1                        White    2106-3  Not Hispanic or Latino
# 2                        White    2106-3  Not Hispanic or Latino
# ...

# %%
display(list(df.columns.values))
# Out:
# ['Notes',
#  'State',
#  'State Code',
#  'Year',
#  'Year Code',
#  'Race',
#  'Race Code',
#  'Hispanic Origin',
#  'Hispanic Origin Code',
#  'ICD Chapter',
#  'ICD Chapter Code',
#  'Deaths',
#  'Population',
#  'Crude Rate']

# %%
df=df.drop(['Notes','State Code','Year Code','Race Code', 'Hispanic Origin Code'], axis = 1)

# %%
df
# Out:
#           State    Year                       Race         Hispanic Origin  \
# 0       Arizona  2013.0                      White  Not Hispanic or Latino
# 1       Arizona  2014.0                      White  Not Hispanic or Latino
# 2      Arkansas  2012.0                      White  Not Hispanic or Latino
# 3      Arkansas  2014.0                      White  Not Hispanic or Latino
# 4    California  2010.0  Asian or Pacific Islander  Not Hispanic or Latino
# ..          ...     ...                        ...                     ...
# 187  Washington  2014.0                      White  Not Hispanic or Latino
# 188   Wisconsin  2011.0                      White  Not Hispanic or Latino
# 189   Wisconsin  2014.0                      White  Not Hispanic or Latino
# 190   Wisconsin  2015.0                      White  Not Hispanic or Latino
# 191         NaN     NaN                        NaN                     NaN
#
# ...

# %%
df = df.fillna('na')

# %%
df
# Out:
#           State    Year                       Race         Hispanic Origin  \
# 0       Arizona  2013.0                      White  Not Hispanic or Latino
# 1       Arizona  2014.0                      White  Not Hispanic or Latino
# 2      Arkansas  2012.0                      White  Not Hispanic or Latino
# 3      Arkansas  2014.0                      White  Not Hispanic or Latino
# 4    California  2010.0  Asian or Pacific Islander  Not Hispanic or Latino
# ..          ...     ...                        ...                     ...
# 187  Washington  2014.0                      White  Not Hispanic or Latino
# 188   Wisconsin  2011.0                      White  Not Hispanic or Latino
# 189   Wisconsin  2014.0                      White  Not Hispanic or Latino
# 190   Wisconsin  2015.0                      White  Not Hispanic or Latino
# 191          na      na                         na                      na
#
# ...

# %%
df = df.fillna('Not Available')

# %%
df
# Out:
#           State    Year                       Race         Hispanic Origin  \
# 0       Arizona  2013.0                      White  Not Hispanic or Latino
# 1       Arizona  2014.0                      White  Not Hispanic or Latino
# 2      Arkansas  2012.0                      White  Not Hispanic or Latino
# 3      Arkansas  2014.0                      White  Not Hispanic or Latino
# 4    California  2010.0  Asian or Pacific Islander  Not Hispanic or Latino
# ..          ...     ...                        ...                     ...
# 187  Washington  2014.0                      White  Not Hispanic or Latino
# 188   Wisconsin  2011.0                      White  Not Hispanic or Latino
# 189   Wisconsin  2014.0                      White  Not Hispanic or Latino
# 190   Wisconsin  2015.0                      White  Not Hispanic or Latino
# 191          na      na                         na                      na
#
# ...

# %%
df.isnull().sum(axis = 0)
# Out:
# State               0
# Year                0
# Race                0
# Hispanic Origin     0
# ICD Chapter         0
# ICD Chapter Code    0
# Deaths              0
# Population          0
# Crude Rate          0
# dtype: int64

# %%
df.drop(df.index[191])
# Out:
#           State    Year                       Race         Hispanic Origin  \
# 0       Arizona  2013.0                      White  Not Hispanic or Latino
# 1       Arizona  2014.0                      White  Not Hispanic or Latino
# 2      Arkansas  2012.0                      White  Not Hispanic or Latino
# 3      Arkansas  2014.0                      White  Not Hispanic or Latino
# 4    California  2010.0  Asian or Pacific Islander  Not Hispanic or Latino
# ..          ...     ...                        ...                     ...
# 186  Washington  2013.0                      White  Not Hispanic or Latino
# 187  Washington  2014.0                      White  Not Hispanic or Latino
# 188   Wisconsin  2011.0                      White  Not Hispanic or Latino
# 189   Wisconsin  2014.0                      White  Not Hispanic or Latino
# 190   Wisconsin  2015.0                      White  Not Hispanic or Latino
#
# ...
