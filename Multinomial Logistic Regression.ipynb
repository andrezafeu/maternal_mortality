# %%
#load all necessary libraries
import pandas as pd 
import numpy as np 
import scipy as scp
import sklearn

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn import metrics 
from sklearn.metrics import confusion_matrix

import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
pd.set_option("max_columns", 80)

# %%
# Read cleaned dataset
df = pd.read_csv('data/interim_data/cdc_data_cleaned_with_ethnicities.csv')
df.head()
# Out:
#            resident_status level_of_education month_of_death  age  \
# 0                RESIDENTS                3.0        January   49
# 1                RESIDENTS                3.0        January   40
# 2                RESIDENTS                9.0          April   35
# 3                RESIDENTS                6.0          April   41
# 4  INTRASTATE NONRESIDENTS                3.0           June   28
#
#         place_of_death_patient_status marital_status day_of_week_of_death  \
# 0  Hospital, clinic or Medical Center       Divorced              Tuesday
# 1  Hospital, clinic or Medical Center        Married               Sunday
# 2  Hospital, clinic or Medical Center        Married               Friday
# 3  Hospital, clinic or Medical Center        Married            Wednesday
# 4  Hospital, clinic or Medical Center        Married               Sunday
#
#    year manner_of_death was_autopsy_done  \
# 0  2015         Natural               No
# 1  2015         Natural               No
# 2  2015         Natural              Yes
# 3  2015         Natural               No
# 4  2015         Natural               No
#
#   place_of_injury_for_icd_w00_y34_except_y06_and_y07_ icd_code_10th_revision  \
# 0                                      Not Available                    O266
# 1                                      Not Available                    O266
# 2                                      Not Available                    O720
# 3                                      Not Available                    O721
# 4                                      Not Available                    O038
#
#                                  358_causes_of_death  \
# 0                  All other direct obstetric causes
# 1                  All other direct obstetric causes
# 2  Hemorrhage of pregnancy and childbirth and pla...
# 3  Hemorrhage of pregnancy and childbirth and pla...
# 4                               Spontaneous abortion
#
#                                  113_causes_of_death  \
# 0  Other complications of pregnancy, childbirth a...
# 1  Other complications of pregnancy, childbirth a...
# 2  Other complications of pregnancy, childbirth a...
# 3  Other complications of pregnancy, childbirth a...
# 4                    Pregnancy with abortive outcome
#
#   130_causes_of_infant_death                           39_cause_recode  \
# 0              Not Available  Pregnancy, childbirth and the puerperium
# 1              Not Available  Pregnancy, childbirth and the puerperium
# 2              Not Available  Pregnancy, childbirth and the puerperium
# 3              Not Available  Pregnancy, childbirth and the puerperium
# 4              Not Available  Pregnancy, childbirth and the puerperium
#
#    number_of_entity_axis_conditions entity_condition_1 entity_condition_2  \
# 0                                 9             11O268             21O988
# 1                                 6             11O995             21O995
# 2                                 3             11O994             21O720
# 3                                 3             11O721             12O991
# 4                                 8             11O996             12O998
#
#   entity_condition_3  number_of_record_axis_conditions record_condition_1  \
# 0             22O992                                 2               O266
# 1             31O266                                 2               O266
# 2             22O991                                 1               O720
# 3              21O95                                 1               O721
# 4             13O995                                 1               O038
#
#   record_condition_2 record_condition_3   race race_recode_3 race_recode_5  \
# 0               O268      Not Available  White         White         White
# 1               O268      Not Available  White         White         White
# 2      Not Available      Not Available  White         White         White
# 3      Not Available      Not Available  White         White         White
# 4      Not Available      Not Available  White         White         White
#
#   hispanic_origin hispanic_originrace_recode ethnicity
# 0         Mexican                    Mexican  Hispanic
# 1         Mexican                    Mexican  Hispanic
# 2         Mexican                    Mexican  Hispanic
# 3         Mexican                    Mexican  Hispanic
# 4         Mexican                    Mexican  Hispanic

# %%
# drop columns
df = df.drop([
    '39_cause_recode', 'entity_condition_2', 'entity_condition_3', 'record_condition_2', 'record_condition_3',
    'race', 'race_recode_3', 'race_recode_5', 'hispanic_origin', 'hispanic_originrace_recode',
    '130_causes_of_infant_death'], axis = 1)

# %%
df
# Out:
#               resident_status level_of_education month_of_death  age  \
# 0                   RESIDENTS                3.0        January   49
# 1                   RESIDENTS                3.0        January   40
# 2                   RESIDENTS                9.0          April   35
# 3                   RESIDENTS                6.0          April   41
# 4     INTRASTATE NONRESIDENTS                3.0           June   28
# ...                       ...                ...            ...  ...
# 7130                RESIDENTS                4.0        October   33
# 7131                RESIDENTS                4.0        October   27
# 7132                RESIDENTS                6.0       December   25
# 7133                RESIDENTS                3.0       December   40
# 7134                RESIDENTS                5.0       December   46
#
#            place_of_death_patient_status         marital_status  \
# 0     Hospital, clinic or Medical Center               Divorced
# 1     Hospital, clinic or Medical Center                Married
# 2     Hospital, clinic or Medical Center                Married
# 3     Hospital, clinic or Medical Center                Married
# 4     Hospital, clinic or Medical Center                Married
# ...                                  ...                    ...
# 7130  Hospital, clinic or Medical Center                Married
# 7131  Hospital, clinic or Medical Center                Married
# 7132  Hospital, clinic or Medical Center  Never married, Single
# 7133  Hospital, clinic or Medical Center  Never married, Single
# 7134  Hospital, clinic or Medical Center               Divorced
#
#      day_of_week_of_death  year manner_of_death was_autopsy_done  \
# 0                 Tuesday  2015         Natural               No
# 1                  Sunday  2015         Natural               No
# 2                  Friday  2015         Natural              Yes
# 3               Wednesday  2015         Natural               No
# 4                  Sunday  2015         Natural               No
# ...                   ...   ...             ...              ...
# 7130              Tuesday  2009   Not Available               No
# 7131             Thursday  2009         Natural               No
# 7132            Wednesday  2009   Not Available               No
# 7133             Saturday  2009         Natural              Yes
# 7134               Friday  2009         Natural              Yes
#
#      place_of_injury_for_icd_w00_y34_except_y06_and_y07_  \
# 0                                         Not Available
# 1                                         Not Available
# 2                                         Not Available
# 3                                         Not Available
# 4                                         Not Available
# ...                                                 ...
# 7130                                      Not Available
# 7131                                      Not Available
# 7132                                      Not Available
# 7133                                      Not Available
# 7134                                      Not Available
#
#                                  icd_code_10th_revision  \
# 0                                                  O266
# 1                                                  O266
# 2                                                  O720
# 3                                                  O721
# 4                                                  O038
# ...                                                 ...
# 7130  Combination of conditions classifiable to O99....
# 7131                          unspecified pre-eclampsia
# 7132  Exhaustion and fatigue, Peripheral neuritis, o...
# 7133                                                O96
# 7134                                               O001
#
#                                     358_causes_of_death  \
# 0                     All other direct obstetric causes
# 1                     All other direct obstetric causes
# 2     Hemorrhage of pregnancy and childbirth and pla...
# 3     Hemorrhage of pregnancy and childbirth and pla...
# 4                                  Spontaneous abortion
# ...                                                 ...
# 7130                          Indirect obstetric deaths
# 7131                        Eclampsia and pre-eclampsia
# 7132                  All other direct obstetric causes
# 7133  Other deaths related to pregnancy, childbirth ...
# 7134                                  Ectopic pregnancy
#
#                                     113_causes_of_death  \
# 0     Other complications of pregnancy, childbirth a...
# 1     Other complications of pregnancy, childbirth a...
# 2     Other complications of pregnancy, childbirth a...
# 3     Other complications of pregnancy, childbirth a...
# 4                       Pregnancy with abortive outcome
# ...                                                 ...
# 7130  Other complications of pregnancy, childbirth a...
# 7131  Other complications of pregnancy, childbirth a...
# 7132  Other complications of pregnancy, childbirth a...
# 7133  Other complications of pregnancy, childbirth a...
# 7134                    Pregnancy with abortive outcome
#
#       number_of_entity_axis_conditions entity_condition_1  \
# 0                                    9             11O268
# 1                                    6             11O995
# 2                                    3             11O994
# 3                                    3             11O721
# 4                                    8             11O996
# ...                                ...                ...
# 7130                                 1             11O998
# 7131                                 2             11O149
# 7132                                 2             11O268
# 7133                                 2              11O96
# 7134                                 2             11O001
#
#       number_of_record_axis_conditions record_condition_1 ethnicity
# 0                                    2               O266  Hispanic
# 1                                    2               O266  Hispanic
# 2                                    1               O720  Hispanic
# 3                                    1               O721  Hispanic
# 4                                    1               O038  Hispanic
# ...                                ...                ...       ...
# 7130                                 1               O998     Black
# 7131                                 1               O149     Black
# 7132                                 1               O268     Black
# 7133                                 1                O96     Black
# 7134                                 1               O001     Black
#
# [7135 rows x 19 columns]

# %%
#Recode values to integer: LinearRegression does not take strings

def recode_to_int(column_name):
    df[column_name] = df[column_name].astype('category')
    df[column_name] = df[column_name].cat.codes

for column in df.columns:
    recode_to_int(column)

# %%
df
# Out:
#       resident_status  level_of_education  month_of_death  age  \
# 0                   3                   1               4   38
# 1                   3                   1               4   29
# 2                   3                   7               0   24
# 3                   3                   4               0   30
# 4                   2                   1               6   17
# ...               ...                 ...             ...  ...
# 7130                3                   2              10   22
# 7131                3                   2              10   16
# 7132                3                   4               2   14
# 7133                3                   1               2   29
# 7134                3                   3               2   35
#
#       place_of_death_patient_status  marital_status  day_of_week_of_death  \
# 0                                 2               0                     5
# 1                                 2               2                     3
# 2                                 2               2                     0
# 3                                 2               2                     6
# 4                                 2               2                     3
# ...                             ...             ...                   ...
# 7130                              2               2                     5
# 7131                              2               2                     4
# 7132                              2               3                     6
# 7133                              2               3                     2
# 7134                              2               0                     0
#
#       year  manner_of_death  was_autopsy_done  \
# 0        6                3                 0
# 1        6                3                 0
# 2        6                3                 2
# 3        6                3                 0
# 4        6                3                 0
# ...    ...              ...               ...
# 7130     0                4                 0
# 7131     0                3                 0
# 7132     0                4                 0
# 7133     0                3                 2
# 7134     0                3                 2
#
#       place_of_injury_for_icd_w00_y34_except_y06_and_y07_  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 7130                                                  1
# 7131                                                  1
# 7132                                                  1
# 7133                                                  1
# 7134                                                  1
#
#       icd_code_10th_revision  358_causes_of_death  113_causes_of_death  \
# 0                         66                    0                    0
# 1                         66                    0                    0
# 2                        104                    3                    0
# 3                        105                    3                    0
# 4                         21                   12                    1
# ...                      ...                  ...                  ...
# 7130                       0                    4                    0
# 7131                     157                    1                    0
# 7132                       6                    0                    0
# 7133                     136                   11                    0
# 7134                       8                    2                    1
#
#       number_of_entity_axis_conditions  entity_condition_1  \
# 0                                    8                  76
# 1                                    5                 146
# 2                                    2                 145
# 3                                    2                 100
# 4                                    7                 147
# ...                                ...                 ...
# 7130                                 0                 149
# 7131                                 1                  57
# 7132                                 1                  76
# 7133                                 1                 127
# 7134                                 1                  27
#
#       number_of_record_axis_conditions  record_condition_1  ethnicity
# 0                                    1                  64          1
# 1                                    1                  64          1
# 2                                    0                 103          1
# 3                                    0                 104          1
# 4                                    0                  13          1
# ...                                ...                 ...        ...
# 7130                                 0                 157          0
# 7131                                 0                  43          0
# 7132                                 0                  65          0
# 7133                                 0                 135          0
# 7134                                 0                   0          0
#
# [7135 rows x 19 columns]

# %%
df['358_causes_of_death'].unique()
# Out:
# array([ 0,  3, 12, 11,  2,  7,  6,  1,  4, 10,  9,  8,  5], dtype=int8)

# %%
df_mlr = df[['ethnicity', 'marital_status', '358_causes_of_death']]
df_mlr
# Out:
#       ethnicity  marital_status  358_causes_of_death
# 0             1               0                    0
# 1             1               2                    0
# 2             1               2                    3
# 3             1               2                    3
# 4             1               2                   12
# ...         ...             ...                  ...
# 7130          0               2                    4
# 7131          0               2                    1
# 7132          0               3                    0
# 7133          0               3                   11
# 7134          0               0                    2
#
# [7135 rows x 3 columns]

# %%
#Create training and test datasets

X = df_mlr.drop(['marital_status', 'ethnicity'], axis=1) 
y = df_mlr['marital_status']

print(list(X.columns.values)) 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.20, random_state = 5)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# ['358_causes_of_death']
# (5708, 1)
# (1427, 1)
# (5708,)
# (1427,)

# %%
model1 = LogisticRegression(
    random_state=0,
    multi_class='multinomial',
    penalty='none',
    solver='newton-cg'
).fit(X_train, y_train)
preds = model1.predict(X_test)

#print the tunable parameters (They were not tuned in, everything kept as default)
params = model1.get_params()
print(params)
# Out:
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'multinomial', 'n_jobs': None, 'penalty': 'none', 'random_state': 0, 'solver': 'newton-cg', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}

# %%
#Print model parameters
print('Intercept: \n', model1.intercept_)
print('Coefficients: \n', model1.coef_)
# Out:
# Intercept:
#  [ 0.28628941 -1.84747825  1.64621018  1.56248096 -1.6475023 ]
# Coefficients:
#  [[-0.00894642]
#  [-0.01622549]
#  [ 0.01895773]
#  [ 0.01913111]
#  [-0.01291694]]

# %%
np.exp(model1.coef_)
# Out:
# array([[0.99109348],
#        [0.98390543],
#        [1.01913857],
#        [1.01931528],
#        [0.98716613]])

# %%
#Use statsmodels to assess variables

logit_model=sm.MNLogit(y_train,sm.add_constant(X_train))
logit_model
result=logit_model.fit()
stats1=result.summary()
stats2=result.summary2()
print(stats1)
print(stats2)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.069263
#          Iterations 7
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:         marital_status   No. Observations:                 5708
# Model:                        MNLogit   Df Residuals:                     5700
# Method:                           MLE   Df Model:                            4
# Date:                Sat, 31 Jul 2021   Pseudo R-squ.:               0.0008285
# Time:                        18:42:53   Log-Likelihood:                -6103.4
# converged:                       True   LL-Null:                       -6108.4
# Covariance Type:            nonrobust   LLR p-value:                   0.03842
# =======================================================================================
#    marital_status=1       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -2.1338      0.183    -11.655      0.000      -2.493      -1.775
# 358_causes_of_death    -0.0073      0.030     -0.239      0.811      -0.067       0.052
# ---------------------------------------------------------------------------------------
#    marital_status=2       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.3599      0.066     20.518      0.000       1.230       1.490
# 358_causes_of_death     0.0279      0.011      2.611      0.009       0.007       0.049
# ---------------------------------------------------------------------------------------
#    marital_status=3       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.2762      0.067     19.090      0.000       1.145       1.407
# 358_causes_of_death     0.0281      0.011      2.607      0.009       0.007       0.049
# ---------------------------------------------------------------------------------------
#    marital_status=4       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -1.9338      0.167    -11.561      0.000      -2.262      -1.606
# 358_causes_of_death    -0.0040      0.028     -0.144      0.886      -0.058       0.050
# =======================================================================================
#                           Results: MNLogit
# ====================================================================
# Model:               MNLogit           Pseudo R-squared:  0.001
# Dependent Variable:  marital_status    AIC:               12222.7053
# Date:                2021-07-31 18:42  BIC:               12275.9023
# No. Observations:    5708              Log-Likelihood:    -6103.4
# Df Model:            4                 LL-Null:           -6108.4
# Df Residuals:        5700              LLR p-value:       0.038419
# Converged:           1.0000            Scale:             1.0000
# No. Iterations:      7.0000
# --------------------------------------------------------------------
#  marital_status = 0  Coef.  Std.Err.    t     P>|t|   [0.025  0.975]
# --------------------------------------------------------------------
#               const -2.1338   0.1831 -11.6554 0.0000 -2.4926 -1.7750
# 358_causes_of_death -0.0073   0.0304  -0.2391 0.8110 -0.0669  0.0524
# --------------------------------------------------------------------
#    marital_status = 1   Coef.  Std.Err.    t    P>|t|  [0.025 0.975]
# --------------------------------------------------------------------
#               const     1.3599   0.0663 20.5176 0.0000 1.2300 1.4898
# 358_causes_of_death     0.0279   0.0107  2.6108 0.0090 0.0070 0.0489
# --------------------------------------------------------------------
#    marital_status = 2   Coef.  Std.Err.    t    P>|t|  [0.025 0.975]
# --------------------------------------------------------------------
#               const     1.2762   0.0669 19.0900 0.0000 1.1452 1.4072
# 358_causes_of_death     0.0281   0.0108  2.6073 0.0091 0.0070 0.0492
# --------------------------------------------------------------------
#  marital_status = 3  Coef.  Std.Err.    t     P>|t|   [0.025  0.975]
# --------------------------------------------------------------------
#               const -1.9338   0.1673 -11.5607 0.0000 -2.2616 -1.6059
# 358_causes_of_death -0.0040   0.0276  -0.1439 0.8856 -0.0580  0.0501
# ====================================================================
